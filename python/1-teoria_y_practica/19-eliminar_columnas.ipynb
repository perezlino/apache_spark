# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Eliminar columnas

# %%
from pyspark.sql.functions import lit, concat, col

employee_data = [(10,"Raj","Kumar","1999","100","M",2000),
                 (20,"Rahul","Rajan","2002","200","f",2000),
                 (30,"Raghav","Manish","2010","100",None,2000),
                 (40,"Raja","Singh","2004","100","F",2000),
                 (50,"Rama","Krish","2008","400","M",2000),
                 (60,"Rasul","Kutty","2014","500","M",2000),
                 (70,"Kumar","Chand","2004","600","M",2000)
                ]
employee_schema = ["employee_id","first_name","last_name","doj",
                   "employee_dept_id","gender","salary"]

df = spark.createDataFrame(data=employee_data, schema=employee_schema)

# %% [markdown]
# #### Eliminar una columna

# %% [markdown]
# ##### Forma 1

# %%
df_modif = df.drop('salary')

display(df_modif)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th></tr></thead><tbody><tr><td>10</td><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td><td>M</td></tr><tr><td>20</td><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td><td>f</td></tr><tr><td>30</td><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td><td>null</td></tr><tr><td>40</td><td>Raja</td><td>Singh</td><td>2004</td><td>100</td><td>F</td></tr><tr><td>50</td><td>Rama</td><td>Krish</td><td>2008</td><td>400</td><td>M</td></tr><tr><td>60</td><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td><td>M</td></tr><tr><td>70</td><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td><td>M</td></tr></tbody></table></div>

# %% [markdown]
# ##### Forma 2

# %%
df_modif = df.drop(col('salary'))

display(df_modif)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th></tr></thead><tbody><tr><td>10</td><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td><td>M</td></tr><tr><td>20</td><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td><td>f</td></tr><tr><td>30</td><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td><td>null</td></tr><tr><td>40</td><td>Raja</td><td>Singh</td><td>2004</td><td>100</td><td>F</td></tr><tr><td>50</td><td>Rama</td><td>Krish</td><td>2008</td><td>400</td><td>M</td></tr><tr><td>60</td><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td><td>M</td></tr><tr><td>70</td><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td><td>M</td></tr></tbody></table></div>

# %% [markdown]
# ##### Forma 3

# %%
df_modif = df.drop(df['salary'])

display(df_modif)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th><th>gender</th></tr></thead><tbody><tr><td>10</td><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td><td>M</td></tr><tr><td>20</td><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td><td>f</td></tr><tr><td>30</td><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td><td>null</td></tr><tr><td>40</td><td>Raja</td><td>Singh</td><td>2004</td><td>100</td><td>F</td></tr><tr><td>50</td><td>Rama</td><td>Krish</td><td>2008</td><td>400</td><td>M</td></tr><tr><td>60</td><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td><td>M</td></tr><tr><td>70</td><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td><td>M</td></tr></tbody></table></div>

# %% [markdown]
# #### Eliminar múltiples columnas

# %% [markdown]
# ##### Forma 1

# %%
df_modif = df.drop('gender').drop('salary')

display(df_modif)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th></tr></thead><tbody><tr><td>10</td><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td></tr><tr><td>20</td><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td></tr><tr><td>30</td><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td></tr><tr><td>40</td><td>Raja</td><td>Singh</td><td>2004</td><td>100</td></tr><tr><td>50</td><td>Rama</td><td>Krish</td><td>2008</td><td>400</td></tr><tr><td>60</td><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td></tr><tr><td>70</td><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td></tr></tbody></table></div>

# %% [markdown]
# ##### Forma 2

# %%
df_modif = df.drop('gender','salary')

display(df_modif)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th></tr></thead><tbody><tr><td>10</td><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td></tr><tr><td>20</td><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td></tr><tr><td>30</td><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td></tr><tr><td>40</td><td>Raja</td><td>Singh</td><td>2004</td><td>100</td></tr><tr><td>50</td><td>Rama</td><td>Krish</td><td>2008</td><td>400</td></tr><tr><td>60</td><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td></tr><tr><td>70</td><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td></tr></tbody></table></div>

# %% [markdown]
# #### Error al utilizar .col para eliminar múltiples columnas

# %%
df_modif = df.drop(col('gender'),col('salary'))

display(df_modif)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-804623631765890> in <cell line: 1>()
# ----> 1 df_modif = df.drop(col('gender'),col('salary'))
#       2
#       3 display(df_modif)
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# /databricks/spark/python/pyspark/sql/dataframe.py in drop(self, *cols)
#    3419             for col in cols:
#    3420                 if not isinstance(col, str):
# -> 3421                     raise TypeError("each col in the param list should be a string")
#    3422             jdf = self._jdf.drop(self._jseq(cols))
#    3423
#
# TypeError: each col in the param list should be a string

# %% [markdown]
# #### Si tenemos un nombre de columna que no existe, la columna será ignorada

# %%
df_modif = df.drop('gender','salary','location')

display(df_modif)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>first_name</th><th>last_name</th><th>doj</th><th>employee_dept_id</th></tr></thead><tbody><tr><td>10</td><td>Raj</td><td>Kumar</td><td>1999</td><td>100</td></tr><tr><td>20</td><td>Rahul</td><td>Rajan</td><td>2002</td><td>200</td></tr><tr><td>30</td><td>Raghav</td><td>Manish</td><td>2010</td><td>100</td></tr><tr><td>40</td><td>Raja</td><td>Singh</td><td>2004</td><td>100</td></tr><tr><td>50</td><td>Rama</td><td>Krish</td><td>2008</td><td>400</td></tr><tr><td>60</td><td>Rasul</td><td>Kutty</td><td>2014</td><td>500</td></tr><tr><td>70</td><td>Kumar</td><td>Chand</td><td>2004</td><td>600</td></tr></tbody></table></div>

# %% [markdown]
# #### Eliminar una lista de columnas

# %%
lista = ['doj','gender','salary']

df_modif = df.drop(*lista)

df_modif.show()
# Out:
# +-----------+----------+---------+----------------+
# |employee_id|first_name|last_name|employee_dept_id|
# +-----------+----------+---------+----------------+
# |         10|       Raj|    Kumar|             100|
# |         20|     Rahul|    Rajan|             200|
# |         30|    Raghav|   Manish|             100|
# |         40|      Raja|    Singh|             100|
# |         50|      Rama|    Krish|             400|
# |         60|     Rasul|    Kutty|             500|
# |         70|     Kumar|    Chand|             600|
# +-----------+----------+---------+----------------+
