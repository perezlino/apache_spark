# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Visualización de procesos en ejecución

# %%
# %sh
ps
# Out:
#   PID TTY          TIME CMD
#     1 ?        00:00:00 systemd
#    40 ?        00:00:00 systemd-journal
#    55 ?        00:00:00 networkd-dispat
#    64 ?        00:00:00 systemd-logind
#    77 ?        00:00:00 ntpd
#    82 ?        00:00:00 monit
#    83 ?        00:00:00 sshd
#    84 ?        00:00:00 unattended-upgr
#   146 ?        00:00:00 start_wsfs.sh
#   153 ?        00:00:00 wsfs
#   274 ?        00:01:21 java
#   349 ?        00:00:00 apache2
#   379 ?        00:00:00 cron
#   419 ?        00:00:00 bash
#   470 ?        00:03:18 java
#   614 ?        00:00:00 ttyd
#   755 ?        00:00:00 bash
#   761 ?        00:00:00 R
#   776 ?        00:00:00 R
#   856 ?        00:00:03 python
#   912 ?        00:00:02 python
#  1225 ?        00:00:01 python
#  1579 ?        00:00:00 check_dbfs_fuse <defunct>
#  1603 ?        00:00:01 python
#  1640 ?        00:00:00 ps
