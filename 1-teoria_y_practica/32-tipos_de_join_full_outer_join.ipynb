# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Tipos de Join --> Full outer join

# %%
from pyspark.sql.functions import lit, concat, col, desc

employee_data = [(10,"Raj","Kumar","1999","100","M",2000,'100'),
                 (20,"Sahul","Rajan","2002","200","F",3000,'200'),
                 (30,"Antonio","Manish","2010","300",None,9000,'300'),
                 (40,"Yaja","Singh","2004","100","F",1000,'200'),
                 (50,"Nama","Krish","2008","400","M",8000,'400'),
                 (60,"Alfonso","Kutty","2014","400","M",7000,'600'),
                 (70,"Tumar","Chand","2004","200","M",7000,'700'),
                 (80,"Andres","Soto","2003","800","M",4000,'700'),
                ]
employee_schema = ["employee_id","first_name","last_name","doj",
                   "dept_id","gender","salary","member_id"]

df = spark.createDataFrame(data=employee_data, schema=employee_schema)
df.printSchema()
# Out:
# root
#  |-- employee_id: long (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- doj: string (nullable = true)
#  |-- dept_id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- member_id: string (nullable = true)

# %%
departamento = [('100','HR'),
                ('200','Supply'),
                ('300','Sales'),
                ('400','Stock'),
                ]
dept_schema = ['dept_id','dept_name']

df_dept = spark.createDataFrame(data=departamento, schema=dept_schema)
df_dept.printSchema()
# Out:
# root
#  |-- dept_id: string (nullable = true)
#  |-- dept_name: string (nullable = true)

# %%
df_join = df.join(df_dept,df.dept_id == df_dept.dept_id,"full")

df_join.show(truncate=False)
# Out:
# +-----------+----------+---------+----+-------+------+------+---------+-------+---------+
# |employee_id|first_name|last_name|doj |dept_id|gender|salary|member_id|dept_id|dept_name|
# +-----------+----------+---------+----+-------+------+------+---------+-------+---------+
# |10         |Raj       |Kumar    |1999|100    |M     |2000  |100      |100    |HR       |
# |40         |Yaja      |Singh    |2004|100    |F     |1000  |200      |100    |HR       |
# |20         |Sahul     |Rajan    |2002|200    |F     |3000  |200      |200    |Supply   |
# |70         |Tumar     |Chand    |2004|200    |M     |7000  |700      |200    |Supply   |
# |30         |Antonio   |Manish   |2010|300    |null  |9000  |300      |300    |Sales    |
# |50         |Nama      |Krish    |2008|400    |M     |8000  |400      |400    |Stock    |
# |60         |Alfonso   |Kutty    |2014|400    |M     |7000  |600      |400    |Stock    |
# |80         |Andres    |Soto     |2003|800    |M     |4000  |700      |null   |null     |
# +-----------+----------+---------+----+-------+------+------+---------+-------+---------+
