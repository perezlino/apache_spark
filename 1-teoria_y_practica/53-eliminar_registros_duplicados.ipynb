# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Eliminar registros duplicados

# %% [markdown]
# **distinct( )** , **dropDuplicates( )** y **drop_duplicates()** cumplen la misma función.

# %%
from pyspark.sql.functions import *

estudiante = [(1,"Alfonso","Science",86,"A",90),
              (1,"Alfonso","Science",86,"A",90),
              (2,"Maria","Math",56,"R",55),
              (3,"Javiera","English",77,"A",85),
              (3,"Javiera","English",77,"A",85),
              (4,"Andres","Science",89,"A",98),
              (5,"Tomas","Math",69,"A",70),
              (5,"Tomas","Math",69,"A",70),
              (6,"Raul",'Phisics',45,"R",50),
              (7,"Pedro","English",61,"A",70)
             ]
schema = ["id","nombre","ramo","puntaje","status","asistencia"]

df = spark.createDataFrame(data=estudiante, schema=schema)
df.printSchema()
df.show()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- nombre: string (nullable = true)
#  |-- ramo: string (nullable = true)
#  |-- puntaje: long (nullable = true)
#  |-- status: string (nullable = true)
#  |-- asistencia: long (nullable = true)
#
# +---+-------+-------+-------+------+----------+
# | id| nombre|   ramo|puntaje|status|asistencia|
# +---+-------+-------+-------+------+----------+
# |  1|Alfonso|Science|     86|     A|        90|
# |  1|Alfonso|Science|     86|     A|        90|
# |  2|  Maria|   Math|     56|     R|        55|
# |  3|Javiera|English|     77|     A|        85|
# |  3|Javiera|English|     77|     A|        85|
# |  4| Andres|Science|     89|     A|        98|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  6|   Raul|Phisics|     45|     R|        50|
# |  7|  Pedro|English|     61|     A|        70|
# +---+-------+-------+-------+------+----------+

# %% [markdown]
# #### dropDuplicates()

# %%
df.dropDuplicates().show()
# Out:
# +---+-------+-------+-------+------+----------+
# | id| nombre|   ramo|puntaje|status|asistencia|
# +---+-------+-------+-------+------+----------+
# |  1|Alfonso|Science|     86|     A|        90|
# |  2|  Maria|   Math|     56|     R|        55|
# |  3|Javiera|English|     77|     A|        85|
# |  4| Andres|Science|     89|     A|        98|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  7|  Pedro|English|     61|     A|        70|
# |  6|   Raul|Phisics|     45|     R|        50|
# +---+-------+-------+-------+------+----------+

# %% [markdown]
# #### drop_duplicates()

# %%
df.drop_duplicates().show()
# Out:
# +---+-------+-------+-------+------+----------+
# | id| nombre|   ramo|puntaje|status|asistencia|
# +---+-------+-------+-------+------+----------+
# |  1|Alfonso|Science|     86|     A|        90|
# |  2|  Maria|   Math|     56|     R|        55|
# |  3|Javiera|English|     77|     A|        85|
# |  4| Andres|Science|     89|     A|        98|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  7|  Pedro|English|     61|     A|        70|
# |  6|   Raul|Phisics|     45|     R|        50|
# +---+-------+-------+-------+------+----------+

# %%
df.drop_duplicates(subset=None).show()
# Out:
# +---+-------+-------+-------+------+----------+
# | id| nombre|   ramo|puntaje|status|asistencia|
# +---+-------+-------+-------+------+----------+
# |  1|Alfonso|Science|     86|     A|        90|
# |  2|  Maria|   Math|     56|     R|        55|
# |  3|Javiera|English|     77|     A|        85|
# |  4| Andres|Science|     89|     A|        98|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  7|  Pedro|English|     61|     A|        70|
# |  6|   Raul|Phisics|     45|     R|        50|
# +---+-------+-------+-------+------+----------+

# %% [markdown]
# #### distinct()

# %%
df.distinct().show()
# Out:
# +---+-------+-------+-------+------+----------+
# | id| nombre|   ramo|puntaje|status|asistencia|
# +---+-------+-------+-------+------+----------+
# |  1|Alfonso|Science|     86|     A|        90|
# |  2|  Maria|   Math|     56|     R|        55|
# |  3|Javiera|English|     77|     A|        85|
# |  4| Andres|Science|     89|     A|        98|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  7|  Pedro|English|     61|     A|        70|
# |  6|   Raul|Phisics|     45|     R|        50|
# +---+-------+-------+-------+------+----------+

# %% [markdown]
# #### Eliminar duplicados basado en una columna(s) especifica(s)

# %%
df.dropDuplicates('id').show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-348697247138785> in <cell line: 1>()
# ----> 1 df.dropDuplicates('id').show()
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# /databricks/spark/python/pyspark/sql/dataframe.py in dropDuplicates(self, subset)
#    2687         """
#    2688         if subset is not None and (not isinstance(subset, Iterable) or isinstance(subset, str)):
# -> 2689             raise TypeError("Parameter 'subset' must be a list of columns")
#    2690
#    2691         if subset is None:
#
# ...

# %%
df.dropDuplicates(['id']).show()
# Out:
# +---+-------+-------+-------+------+----------+
# | id| nombre|   ramo|puntaje|status|asistencia|
# +---+-------+-------+-------+------+----------+
# |  1|Alfonso|Science|     86|     A|        90|
# |  2|  Maria|   Math|     56|     R|        55|
# |  3|Javiera|English|     77|     A|        85|
# |  4| Andres|Science|     89|     A|        98|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  6|   Raul|Phisics|     45|     R|        50|
# |  7|  Pedro|English|     61|     A|        70|
# +---+-------+-------+-------+------+----------+

# %%
df.dropDuplicates(subset = ['id']).show()
# Out:
# +---+-------+-------+-------+------+----------+
# | id| nombre|   ramo|puntaje|status|asistencia|
# +---+-------+-------+-------+------+----------+
# |  1|Alfonso|Science|     86|     A|        90|
# |  2|  Maria|   Math|     56|     R|        55|
# |  3|Javiera|English|     77|     A|        85|
# |  4| Andres|Science|     89|     A|        98|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  6|   Raul|Phisics|     45|     R|        50|
# |  7|  Pedro|English|     61|     A|        70|
# +---+-------+-------+-------+------+----------+

# %%
df.dropDuplicates(['id','ramo']).show()
# Out:
# +---+-------+-------+-------+------+----------+
# | id| nombre|   ramo|puntaje|status|asistencia|
# +---+-------+-------+-------+------+----------+
# |  1|Alfonso|Science|     86|     A|        90|
# |  2|  Maria|   Math|     56|     R|        55|
# |  3|Javiera|English|     77|     A|        85|
# |  4| Andres|Science|     89|     A|        98|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  6|   Raul|Phisics|     45|     R|        50|
# |  7|  Pedro|English|     61|     A|        70|
# +---+-------+-------+-------+------+----------+

# %%
df.drop_duplicates(['id','ramo']).show()
# Out:
# +---+-------+-------+-------+------+----------+
# | id| nombre|   ramo|puntaje|status|asistencia|
# +---+-------+-------+-------+------+----------+
# |  1|Alfonso|Science|     86|     A|        90|
# |  2|  Maria|   Math|     56|     R|        55|
# |  3|Javiera|English|     77|     A|        85|
# |  4| Andres|Science|     89|     A|        98|
# |  5|  Tomas|   Math|     69|     A|        70|
# |  6|   Raul|Phisics|     45|     R|        50|
# |  7|  Pedro|English|     61|     A|        70|
# +---+-------+-------+-------+------+----------+
