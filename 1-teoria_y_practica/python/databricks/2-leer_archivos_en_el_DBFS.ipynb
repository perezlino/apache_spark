# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Leer archivos/directorios en el DBFS

# %%
# %fs
ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs
ls dbfs:/FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs
ls /FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.ls("/FileStore/tables/")
# Out:
# Out[2]: [FileInfo(path='dbfs:/FileStore/tables/2010_12_01.csv', name='2010_12_01.csv', size=275001, modificationTime=1650252460000),
#  FileInfo(path='dbfs:/FileStore/tables/2010_summary.json', name='2010_summary.json', size=21353, modificationTime=1656288090000),
#  FileInfo(path='dbfs:/FileStore/tables/AB_NYC_2019.csv', name='AB_NYC_2019.csv', size=7077973, modificationTime=1652188525000),
#  FileInfo(path='dbfs:/FileStore/tables/Paises.json', name='Paises.json', size=438, modificationTime=1661131227000),
#  FileInfo(path='dbfs:/FileStore/tables/archivo.json', name='archivo.json', size=200, modificationTime=1656197245000),
#  FileInfo(path='dbfs:/FileStore/tables/archivo_json.json', name='archivo_json.json', size=325, modificationTime=1653188450000),
#  FileInfo(path='dbfs:/FileStore/tables/baby_names_input/', name='baby_names_input/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/baby_names_output/', name='baby_names_output/', size=0, modificationTime=0),
# ...

# %%
for folder_name in dbutils.fs.ls('/'):
    print(folder_name)
# Out:
# FileInfo(path='dbfs:/FileStore/', name='FileStore/', size=0, modificationTime=0)
# FileInfo(path='dbfs:/IAC/', name='IAC/', size=0, modificationTime=0)
# FileInfo(path='dbfs:/checkpoint220819/', name='checkpoint220819/', size=0, modificationTime=0)
# FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0)
# FileInfo(path='dbfs:/databricks-results/', name='databricks-results/', size=0, modificationTime=0)
# FileInfo(path='dbfs:/mnt/', name='mnt/', size=0, modificationTime=0)
# FileInfo(path='dbfs:/user/', name='user/', size=0, modificationTime=0)

# %%
# %fs
head dbfs:/FileStore/tables/AB_NYC_2019.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 65536 bytes]
# id,name,host_id,host_name,neighbourhood_group,neighbourhood,latitude,longitude,room_type,price,minimum_nights,number_of_reviews,last_review,reviews_per_month,calculated_host_listings_count,availability_365
# 2539,Clean &amp; quiet apt home by the park,2787,John,Brooklyn,Kensington,40.64749,-73.97237,Private room,149,1,9,2018-10-19,0.21,6,365
# 2595,Skylit Midtown Castle,2845,Jennifer,Manhattan,Midtown,40.75362,-73.98377,Entire home/apt,225,1,45,2019-05-21,0.38,2,355
# 3647,THE VILLAGE OF HARLEM....NEW YORK !,4632,Elisabeth,Manhattan,Harlem,40.80902,-73.9419,Private room,150,3,0,,,1,365
# ...
